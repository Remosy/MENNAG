# %%
from nodes import Root
from visualizer.individualvisualizer import IndividualVisualizer
import pdb
#pdb.set_trace()
r = Root()
r.generate()
nn = r.compile()

# %%
nn.compile()
r.child.max_depth_from_current()
# Out:
# 2

# %%
v = IndividualVisualizer(r)
v.draw_tree()

# %%
r.insert_div()
r.compile()
v.draw_tree()

# %%
v.draw_nn()
