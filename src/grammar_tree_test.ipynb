# %%
from nodes import Root, Div, Clones, Clone, Conn, Conns
from visualizer.individualvisualizer import IndividualVisualizer
from ea import EA
import pdb
#pdb.set_trace()
ea = EA()
ea.load_config('settings/bipedal_default.json')
r1 = Root(ea.config)
r1.generate()
r2 = Root(ea.config)
r2.generate()

# %%
v1 = IndividualVisualizer(r1)
v1.draw_tree()

# %%
for i in range(100):
    r1.mutate()
    r1.compile()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0c5334cd1c4f> in <module>
#       1 for i in range(100):
#       2     r1.mutate()
# ----> 3     r1.compile()
#
# ~/Documents/MENNAG/src/nodes.py in compile(self)
#      38     def compile(self):
#      39         self.child[0].ID = ''
# ---> 40         self.child[0].compile()
#      41         self.neuronSet = self.child[0].neuronSet
#      42         self.connSet = self.child[0].connSet
#
# ~/Documents/MENNAG/src/nodes.py in compile(self)
#     354         else:
#     355             self.child[0].compile()
# --> 356             self.child[1].compile()
#     357             self.child[2].compile()
#     358         self.merge_from_children()
#
# ~/Documents/MENNAG/src/nodes.py in compile(self)
#     397             self.child[0].ID = self.ID + '0'
#     398             self.child[1].ID = self.ID + '1'
# --> 399             self.child[0].compile()
#     400             self.child[1].compile()
#     401         else:
#
# ~/Documents/MENNAG/src/nodes.py in compile(self)
#     431             self.neuronSet.add(copy)
#     432         for conn in self.sibling.connSet:
# --> 433             sourceCopy = self.ID + conn[0][sibDepth:]
#     434             targetCopy = self.ID + conn[1][sibDepth:]
#     435             self.connSet.add((sourceCopy, targetCopy, conn[2]))
#
# KeyboardInterrupt:

# %%
r1.execute()
v1.draw_nn()
